# %%
import pandas as pd

# %%
df = pd.read_csv("../data/raw/boi_transactions.csv")

# %%
print("Dataset Shape:", df.shape)
# Out:
# Dataset Shape: (9082, 3925)

# %%
pd.Series(df.columns)
# Out:
# 0       Unnamed: 0
# 1               F1
# 2               F2
# 3               F3
# 4               F4
#            ...
# 3920         F3920
# 3921         F3921
# 3922         F3922
# 3923         F3923
# 3924         F3924
# Length: 3925, dtype: str
